# %% [markdown]
# # 内核测试
#
# 测试 Python 环境是否正确配置。

# %%
import sys
print(f"Python 版本: {sys.version}")
print(f"Python 可执行文件: {sys.executable}")
# Out:
# Python 版本: 3.10.19 (main, Dec  9 2025, 19:17:38) [Clang 21.1.4 ]
# Python 可执行文件: /Users/fang/Documents/Code/python-demo/stock-analysis/.venv/bin/python3

# %%
import pandas as pd
import numpy as np
import matplotlib
import yfinance as yf
import seaborn as sns

print("✓ 所有依赖库导入成功！")
print(f"pandas 版本: {pd.__version__}")
print(f"numpy 版本: {np.__version__}")
print(f"matplotlib 版本: {matplotlib.__version__}")
print(f"yfinance 版本: {yf.__version__}")
print(f"seaborn 版本: {sns.__version__}")
# Out:
# ✓ 所有依赖库导入成功！
# pandas 版本: 2.3.3
# numpy 版本: 2.2.6
# matplotlib 版本: 3.10.8
# yfinance 版本: 1.0
# seaborn 版本: 0.13.2

# %%
import os
import sys

notebook_dir = os.getcwd()
project_dir = os.path.dirname(notebook_dir)
print(f"Notebook 目录: {notebook_dir}")
print(f"项目目录: {project_dir}")

if project_dir not in sys.path:
    sys.path.insert(0, project_dir)
    print(f"已添加到 sys.path: {project_dir}")
else:
    print(f"已在 sys.path 中")
# Out:
# Notebook 目录: /Users/fang/Documents/Code/python-demo/stock-analysis/notebooks
# 项目目录: /Users/fang/Documents/Code/python-demo/stock-analysis
# 已在 sys.path 中

# %%
from src.data_loader import load_stock_data
from src.indicators import calculate_technical_indicators
from src.visualization import plot_price_trend

print("✓ 所有项目模块导入成功！")
# Out:
# ✓ 所有项目模块导入成功！

# %% [markdown]
# ## 总结
#
# 如果所有单元格都成功运行，说明环境配置正确！
#
# 现在可以运行其他 notebook 了。
